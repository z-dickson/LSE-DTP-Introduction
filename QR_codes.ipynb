# %%
pip install qrcode
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install image
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 16.5 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for image: filename=image-1.5.33-py2.py3-none-any.whl size=19482 sha256=256992d5a402e6692269ffc0b73f35b08e437f9a1cd86d64602c2739dd33b1c3
#   Stored in directory: /home/zach/.cache/pip/wheels/58/30/d8/3212cd83eeeeee0a1f0c7b9b7bd0674a2b9f09342870473a2a
# Successfully built image
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode
from PIL import Image

# %%
def create_QR(url, file_name): 
    qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
        )
    qr.add_data(url)
    qr.make(fit=True)
    img = qr.make_image(back_color="white", fill_color=(224, 17, 43))
    img.save('./images/' + file_name + ".png")

# %%
# DSI PhD Affiliate Scheme
create_QR("'https://www.lse.ac.uk/dsi/News/2024/PhD-Affiliate-Scheme-launch'",
          "DSI_phd_affiliate_scheme")

# %%
# Digital Skills Lab
create_QR("'https://info.lse.ac.uk/current-students/digital-skills-lab'",
          "digital_skills_lab")

# %%
# Student Wellbeing
create_QR("'https://info.lse.ac.uk/current-students/student-wellbeing'",
          "student_wellbeing")

# %%
# Research Centres 
create_QR("'https://info.lse.ac.uk/staff/research-centres-and-groups'",
          "research_centres")

# %%
# Grantham Research Institute

create_QR("'https://www.lse.ac.uk/granthaminstitute/'",
            "grantham_research_institute")

# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# set unlimited columns 
pd.set_option('display.max_columns', None)

df = pd.read_csv('/home/zach/Downloads/DNA+Student+Survey_November+6,+2024_12 (2).35/DNA Student Survey_November 6, 2024_12.35.csv')

col_header = df.loc[:2]

df = df.loc[3:]

col_header
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"Europe/Lon...
# 2                                2024-09-25 12:45:18
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"Europe/London"}  {"ImportId":"status"}
# 2                                2024-10-02 09:53:08             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# 1  {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}
# 2            158.143.37.173                        1                   594470
#
#                   Finished                                       RecordedDate  \
# ...

# %%
df.head()
# Out:
#              StartDate              EndDate      Status       IPAddress  \
# 3  2024-09-25 13:58:26  2024-10-02 11:33:53  IP Address  158.143.178.66
# 4  2024-10-16 13:00:43  2024-10-16 13:20:57  IP Address  158.143.208.45
# 5  2024-10-16 14:28:25  2024-10-16 14:40:56  IP Address  158.143.224.85
# 6  2024-10-16 21:56:07  2024-10-17 01:24:08  IP Address  185.240.196.28
# 7  2024-10-17 17:48:56  2024-10-17 18:00:42  IP Address   46.208.21.193
#
#   Progress Duration (in seconds) Finished         RecordedDate  \
# 3        0                596126    False  2024-10-09 11:33:59
# 4      100                  1213     True  2024-10-16 13:20:57
# 5      100                   750     True  2024-10-16 14:40:56
# 6      100                 12480     True  2024-10-17 01:24:09
# 7      100                   705     True  2024-10-17 18:00:42
#
#           ResponseId RecipientLastName RecipientFirstName RecipientEmail  \
# 3  R_229JlqJVBrFI5XA               NaN                NaN            NaN
# ...

# %%
cols = ['Knowledge Base_1','Personal Effectivnes_1','Research_1', 'Engagement_1']

df[cols] = df[cols].astype(float)

df[cols].hist()
# Out:
# array([[<Axes: title={'center': 'Knowledge Base_1'}>,
#         <Axes: title={'center': 'Personal Effectivnes_1'}>],
#        [<Axes: title={'center': 'Research_1'}>,
#         <Axes: title={'center': 'Engagement_1'}>]], dtype=object)

# %%
df['Work on'].value_counts()
# Out:
# Work on
# Knowledge and Intellectual Abilities,Personal Effectiveness                  7
# Personal Effectiveness,Engagement, Influence, and Impact                     4
# Knowledge and Intellectual Abilities,Research Governance and Organisation    3
# Knowledge and Intellectual Abilities,Engagement, Influence, and Impact       2
# Knowledge and Intellectual Abilities                                         2
# Research Governance and Organisation,Engagement, Influence, and Impact       1
# Personal Effectiveness,Research Governance and Organisation                  1
# Name: count, dtype: int64
